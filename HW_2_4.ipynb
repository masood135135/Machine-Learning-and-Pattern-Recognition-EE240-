# %% [markdown]
# # Loading Data and separating 4 and 9 numbers

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import fetch_mldata
#downloding mnist data
mnist = fetch_mldata('MNIST original')

X = mnist.data
y = mnist.target

X4=X[y==4];  X9=X[y==9];
y4=y[y==4]; y9=y[y==9];


X4_train=X4[0:4000,:];  X9_train=X9[0:4000,:]; 
X4_test=X4[4000:,:]; X9_test=X9[4000:,:]

y4_train=y4[0:4000];  y9_train=y9[0:4000]; 
y4_test=y4[4000:]; y9_test=y9[4000:]

X_train=np.vstack((X4_train,X9_train));
y_train=np.concatenate((y4_train,y9_train));

X_test=np.vstack((X4_test,X9_test));
y_test=np.concatenate((y4_test,y9_test));

# %% [markdown]
# # Finding Optimum C for kernel='poly' and degree=1

# %%
#degree 1

clf= svm.SVC(C=0.001,kernel='poly',degree=1)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_

Pe = 1 - clf.score(X_test,y_test)

print('Support Vector ={}   Error={} for C=0.001'.format(len(S_V),Pe))


clf= svm.SVC(C=0.01,kernel='poly',degree=1)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=0.01'.format(len(S_V),Pe))


clf= svm.SVC(C=0.1,kernel='poly',degree=1)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=0.1'.format(len(S_V),Pe))


clf= svm.SVC(C=1,kernel='poly',degree=1)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=1'.format(len(S_V),Pe))


clf= svm.SVC(C=10,kernel='poly',degree=1)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=10'.format(len(S_V),Pe))
# Out:
# Support Vector =831   Error=0.032514700795572504 for C=0.001
# Support Vector =641   Error=0.032514700795572504 for C=0.01
# Support Vector =557   Error=0.03631961259079908 for C=0.1
# Support Vector =492   Error=0.0423728813559322 for C=1
# Support Vector =468   Error=0.04929090280179871 for C=10

# %% [markdown]
# # # Finding Optimum C for kernel='poly' and degree=2

# %%
#degree 2 

clf= svm.SVC(C=0.001,kernel='poly',degree=2)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=0.001'.format(len(S_V),Pe))


clf= svm.SVC(C=0.01,kernel='poly',degree=2)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=0.01'.format(len(S_V),Pe))

clf= svm.SVC(C=0.1,kernel='poly',degree=2)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=0.1'.format(len(S_V),Pe))


clf= svm.SVC(C=1,kernel='poly',degree=2)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=1'.format(len(S_V),Pe))
# Out:
# Support Vector =675   Error=0.011068834313386344 for C=0.001
# Support Vector =675   Error=0.011068834313386344 for C=0.01
# Support Vector =675   Error=0.011068834313386344 for C=0.1
# Support Vector =675   Error=0.011068834313386344 for C=1

# %% [markdown]
# #  Finding Optimum C for kernel='rbf'

# %%
# rbf
clf= svm.SVC(C=0.001,kernel='rbf')
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=0.001'.format(len(S_V),Pe))



clf= svm.SVC(C=0.01,kernel='rbf')
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=0.01'.format(len(S_V),Pe))


clf= svm.SVC(C=0.1,kernel='rbf')
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=0.1'.format(len(S_V),Pe))


clf= svm.SVC(C=1,kernel='rbf')
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=1'.format(len(S_V),Pe))



clf= svm.SVC(C=10,kernel='rbf')
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=10'.format(len(S_V),Pe))
# Out:
# Support Vector =8000   Error=0.48305084745762716 for C=0.001
# Support Vector =8000   Error=0.48305084745762716 for C=0.01
# Support Vector =8000   Error=0.48305084745762716 for C=0.1
# Support Vector =8000   Error=0.48305084745762716 for C=1
# Support Vector =8000   Error=0.48305084745762716 for C=1

# %% [markdown]
# #  Finding Optimum gamma for kernel='rbf' #

# %%
# rbf
clf= svm.SVC(C=1,kernel='rbf', gamma=0.000001)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for gamma=0.000001'.format(len(S_V),Pe))



clf= svm.SVC(C=1,kernel='rbf', gamma=0.00001)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for gamma=0.00001'.format(len(S_V),Pe))


clf= svm.SVC(C=1,kernel='rbf', gamma=0.0001)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for gamma=0.0001'.format(len(S_V),Pe))


clf= svm.SVC(C=1,kernel='rbf', gamma=0.001)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for gamma=0.001'.format(len(S_V),Pe))


clf= svm.SVC(C=1,kernel='rbf', gamma=0.01)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for gamma=0.01'.format(len(S_V),Pe))
# Out:
# Support Vector =3415   Error=0.010377032168799705 for gamma=0.000001
# Support Vector =8000   Error=0.4034936008301626 for gamma=0.00001
# Support Vector =8000   Error=0.48841231407817365 for gamma=0.0001
# Support Vector =8000   Error=0.4635074368730543 for gamma=0.001
# Support Vector =8000   Error=0.48841231407817365 for gamma=0.01

# %% [markdown]
# # Plotting data that violatethe margin by the greatest amount- kernel='poly' degree 1 #

# %%
clf= svm.SVC(C=0.001,kernel='poly',degree=1)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_

Pe = 1 - clf.score(X_test,y_test)

d=np.abs(clf.decision_function(X_test))
d_index=np.argsort(d)

X_hard=X_test[d_index[1:16],:]
f, axarr = plt.subplots(4, 4)
for j in range (4):
    for jj in range (4):
        axarr[j, jj].imshow(X_hard[(j+j),:].reshape((28,28)), cmap='gray')
        axarr[j, jj].set_title(y_test[d_index[4*j+jj]])
        axarr[j, jj].axes.get_xaxis().set_visible(False)
        axarr[j,jj].axes.get_yaxis().set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="852">

# %% [markdown]
# # Plotting data that violatethe margin by the greatest amount- kernel='poly' degree 2 #

# %%
clf= svm.SVC(C=1,kernel='poly',degree=2)
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=1'.format(len(S_V),Pe))


d=np.abs(clf.decision_function(X_test))
d_index=np.argsort(d)

X_hard=X_test[d_index[1:16],:]
f, axarr = plt.subplots(4, 4)
for j in range (4):
    for jj in range (4):
        axarr[j, jj].imshow(X_hard[(j+j),:].reshape((28,28)), cmap='gray')
        axarr[j, jj].set_title(y_test[d_index[4*j+jj]])
        axarr[j, jj].axes.get_xaxis().set_visible(False)
        axarr[j,jj].axes.get_yaxis().set_visible(False)
plt.show()
# Out:
# Support Vector =675   Error=0.011068834313386344 for C=1
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # # Plotting data that violatethe margin by the greatest amount- kernel='rbf' degree 2 #

# %%
# rbf
clf= svm.SVC(C=0.001,kernel='rbf')
clf.fit(X_train,y_train)
S_V=clf.support_vectors_
Pe = 1 - clf.score(X_test,y_test)
print('Support Vector ={}   Error={} for C=0.001'.format(len(S_V),Pe))
d=np.abs(clf.decision_function(X_test))
d_index=np.argsort(d)

X_hard=X_test[d_index[1:16],:]
f, axarr = plt.subplots(4, 4)
for j in range (4):
    for jj in range (4):
        axarr[j, jj].imshow(X_hard[(j+j),:].reshape((28,28)), cmap='gray')
        axarr[j, jj].set_title(y_test[d_index[4*j+jj]])
        axarr[j, jj].axes.get_xaxis().set_visible(False)
        axarr[j,jj].axes.get_yaxis().set_visible(False)
plt.show()
# Out:
# Support Vector =8000   Error=0.48305084745762716 for C=0.001
# <img src="data:image/png;base64,..." width="640">
