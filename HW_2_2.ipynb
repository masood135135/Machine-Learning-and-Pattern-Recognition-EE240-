# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # part a

# %%
x=np.random.rand(100,2)
x1=np.ones(100).reshape(100,1)
w=np.ones(2).reshape(2,1)
y=np.sign(x.dot(w)-1)
Data=np.hstack((y,x1,x))
Data1_train=Data[0:80,:]
Data1_test=Data[81:100,:]
Data2_train=Data[0:30,:]
Data2_test=Data[31:100,:]

# %% [markdown]
# # part b

# %%
w=np.array([[0,0,0]]).reshape(3,1)
def h(w,X):
    return np.sign(X.dot(w))

for i in range (0,80):
        w = w + 0.5*(Data1_train[i,0]-h(w,Data1_train[i,1:4]))*Data1_train[i,1:4].reshape(3,1);
print(w)
# Out:
# [[-1.5       ]
#  [ 1.36013779]
#  [ 1.82536307]]

# %% [markdown]
# # part d

# %%
y_cal=np.sign((Data1_train[:,1:4].dot(w)))
y_cor=np.sign(Data1_train[:,2:4].dot(np.array([1, 1]))-1)
tp=y_cal==np.ones(80).reshape(80,1)*1
tp_b=(y_cal==y_cor)*1
tp=tp_b*tp

fp=y_cal==np.ones(80).reshape(80,1)*1
fp_b=(y_cal!=y_cor)*1
fp=fp_b*fp

fn=y_cal==np.ones(80).reshape(80,1)*-1
fn_b=(y_cal!=y_cor)*1
fn=fn_b*fn

Precision=np.sum(tp)/(np.sum(tp)+np.sum(fp))

Recall=np.sum(tp)/(np.sum(tp)+np.sum(fn))

f1_score=2*(Precision*Recall)/(Precision+Recall)

print('Precision={}\nRecall={}\nf1_score={}'.format(Precision,Recall,f1_score))
# Out:
# Precision=0.525
# Recall=0.6125
# f1_score=0.5653846153846154

# %% [markdown]
# # part c

# %%
plt.figure()
h=np.arange(0,1, 0.001); 
plt.plot(Data[Data[:,0]==1,2],Data[Data[:,0]==1,3],'o',Data[Data[:,0]==-1,2],Data[Data[:,0]==-1,3],'+',h,(-w[0]-w[1]*h)/w[2])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Data #1')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#h=np.arange(1000)/1000;
plt.figure()
h=np.arange(0,1, 0.001); 
plt.plot(Data1_train[Data1_train[:,0]==1,2],Data1_train[Data1_train[:,0]==1,3],'o',Data1_train[Data1_train[:,0]==-1,2],Data1_train[Data1_train[:,0]==-1,3],'+',h,(-w[0]-w[1]*h)/w[2])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Train Data #1')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure() 
h=np.arange(0,1, 0.001); 
plt.plot(Data1_test[Data1_test[:,0]==1,2],Data1_test[Data1_test[:,0]==1,3],'o',Data1_test[Data1_test[:,0]==-1,2],Data1_test[Data1_test[:,0]==-1,3],'+',h,(-w[0]-w[1]*h)/w[2])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Test Data #1')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
w=np.array([[0,0,0]]).reshape(3,1)
def h(w,X):
    return np.sign(X.dot(w))

for i in range (30):
        w = w + 0.5*(Data2_train[i,0]-h(w,Data2_train[i,1:4]))*Data2_train[i,1:4].reshape(3,1);
print(w)
# Out:
# [[-0.5       ]
#  [ 0.18972885]
#  [ 0.81044469]]

# %%
plt.figure()

h=np.arange(0,1, 0.001);
plt.plot(Data2_train[Data2_train[:,0]==1,2],Data2_train[Data2_train[:,0]==1,3],'o',Data2_train[Data2_train[:,0]==-1,2],Data2_train[Data2_train[:,0]==-1,3],'+',h,(-w[0]-w[1]*h)/w[2])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Train Data2')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
h=np.arange(0,1, 0.001);
plt.plot(Data2_test[Data2_test[:,0]==1,2],Data2_test[Data2_test[:,0]==1,3],'o',Data2_test[Data2_test[:,0]==-1,2],Data2_test[Data2_test[:,0]==-1,3],'+',h,(-w[0]-w[1]*h)/w[2])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Test Data #2')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
alpha=np.ones(80)*1e-7

for j in range (80):
        y_h=np.sign(sum(alpha*Data1_train[:,0]*(Data1_train[j,1:4]@Data1_train[:,1:4].T)))
        if (y_h != Data1_train[j,0]):
            alpha[j]=alpha[j]+1;
            
w=np.sum(alpha.reshape(80,1)*Data1_train[:,0].reshape(80,1)*Data1_train[:,1:4],axis=0)

# %%
plt.figure()
h=np.arange(0,1, 0.001);
plt.plot(Data[Data[:,0]==1,2],Data[Data[:,0]==1,3],'o',Data[Data[:,0]==-1,2],Data[Data[:,0]==-1,3],'+',h,(-w[0]-w[1]*h)/w[2])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('All data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
h=np.arange(1000)/1000; 
plt.plot(Data1_train[Data1_train[:,0]==1,2],Data1_train[Data1_train[:,0]==1,3],'o',Data1_train[Data1_train[:,0]==-1,2],Data1_train[Data1_train[:,0]==-1,3],'+',h,(-w[0]-w[1]*h)/w[2])
plt.xlabel('X1)')
plt.ylabel('X2')
plt.title('Train Data1')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
h=np.arange(0,1, 0.001);
plt.plot(Data1_test[Data1_test[:,0]==1,2],Data1_test[Data1_test[:,0]==1,3],'o',Data1_test[Data1_test[:,0]==-1,2],Data1_test[Data1_test[:,0]==-1,3],'+',h,(-w[0]-w[1]*h)/w[2])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Test Data1')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # part e

# %%
alpha=np.zeros(30)*1e-1


for j in range (30):
        y_h=np.sign(sum(alpha*Data2_train[:,0]*(Data2_train[j,1:4]@Data2_train[:,1:4].T)))
        if (y_h != Data2_train[j,0]):
            alpha[j]=alpha[j]+1;
            
w=np.sum(alpha.reshape(30,1)*Data2_train[:,0].reshape(30,1)*Data2_train[:,1:4],axis=0)
print(w)
# Out:
# [-1.          1.05461634  1.01503112]

# %%
plt.figure()
h=np.arange(1000)/1000; 
plt.plot(Data2_train[Data2_train[:,0]==1,2],Data2_train[Data2_train[:,0]==1,3],'o',Data2_train[Data2_train[:,0]==-1,2],Data2_train[Data2_train[:,0]==-1,3],'+',h,(-w[0]-w[1]*h)/w[2])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Train Data2')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
