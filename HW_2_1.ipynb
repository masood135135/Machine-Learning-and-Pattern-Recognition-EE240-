# %% [markdown]
# # Preparing mnist data

# %%
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt


#Downloading data
from sklearn.datasets import fetch_mldata
mnist = fetch_mldata('MNIST original')

#building test and train data

X = mnist.data
y = mnist.target
# getting 0 and 1 numbers
X0=X[y==0,:]
X1=X[y==1,:]
y0=y[y==0]
y1=y[y==1]
X=np.vstack((X0,X1))
y=yt=np.concatenate((y0,y1))

#normolize the data for better convergence
PP= ((X - np.mean(X, axis=0)) / np.std(X, axis=0))
X[:,np.std(X, axis=0) !=0 ]=PP[:,np.std(X, axis=0) !=0 ]

DD=np.hstack((y.reshape(14780,1),X))
DD=DD[np.random.permutation(14780),:]

X_train=DD[:10000,1:]; y_train=DD[:10000,0]
X_test=DD[10000:,1:]; y_test=DD[10000:,0]
# Out:
# C:\Users\masood135\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# # Gradient asent algorithm

# %%
# gradient calculations
def logistic_func(theta, x):
    return 1 / (1 + np.exp(-x.dot(theta)))

def log_gradient(theta, x, y):
    return (logistic_func(theta, x) - y).T.dot(x)

def cost_func(theta, x, y):
    log_func_v = logistic_func(theta,x)
    return np.mean(-y * np.log(log_func_v)-(1-y) * np.log(1 - log_func_v))

def grad_aesc(theta_values, X, y, lr=.001, converge_change=.001):
    cost_iter = []
    cost = cost_func(theta_values, X, y)
    cost_iter.append([0, cost])
    change_cost = 1
    i = 1
    while(change_cost > converge_change):
        old_cost = cost
        theta_values = theta_values - (lr * log_gradient(theta_values, X, y))
        cost = cost_func(theta_values, X, y)
        cost_iter.append([i, cost])
        change_cost = old_cost - cost
        i+=1
    return theta_values, np.array(cost_iter)

# %% [markdown]
# # solvimg mnist data

# %%
# getting weights
shape = X_r.shape[1]
w = np.zeros(shape)
fitted_values, cost_iter = grad_aesc(w, X_train, y_train)
print(fitted_values)

# test the learning 

def prediction_values(theta, X):
    pred_prob = logistic_func(theta, X)
    pred_value = np.where(pred_prob >= .5, 1, 0)
    return pred_prob

a=prediction_values(fitted_values, X_test)
er=np.sum(np.logical_xor(a,y_t)*1)/4780
print(er*100)
# Out:
# [ 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00 -6.050000e-02
#  -6.050000e-02 -6.050000e-02  8.100000e-02  8.300000e-02  1.650000e-02
#   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00 -6.050000e-02
#  -6.050000e-02  0.000000e+00 -6.050000e-02 -6.850000e-02 -6.050000e-02
# ...
